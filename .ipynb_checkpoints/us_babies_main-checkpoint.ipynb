# %%
import pandas as pd

us_babies = pd.read_csv(
    r'D:\MiniForge\Ex_Files_Intro_to_Data_Science\Ex_Files_Intro_to_Data_Science\Exercise Files\us_baby_names.csv'
)

us_babies.head()
# Out:
#    Id       Name  Year Gender  Count
# 0   1       Mary  1880      F   7065
# 1   2       Anna  1880      F   2604
# 2   3       Emma  1880      F   2003
# 3   4  Elizabeth  1880      F   1939
# 4   5     Minnie  1880      F   1746

# %%
us_babies_2014 = us_babies.loc[us_babies['Year'] == 2014, :]

# %%
us_babies_2014
# Out:
#               Id      Name  Year Gender  Count
# 1792389  1792390      Emma  2014      F  20799
# 1792390  1792391    Olivia  2014      F  19674
# 1792391  1792392    Sophia  2014      F  18490
# 1792392  1792393  Isabella  2014      F  16950
# 1792393  1792394       Ava  2014      F  15586
# ...          ...       ...   ...    ...    ...
# 1825428  1825429    Zykeem  2014      M      5
# 1825429  1825430    Zymeer  2014      M      5
# 1825430  1825431   Zymiere  2014      M      5
# 1825431  1825432     Zyran  2014      M      5
# 1825432  1825433     Zyrin  2014      M      5
#
# [33044 rows x 5 columns]

# %%
us_babies_2014.sort_values('Count', ascending=False)
# Out:
#               Id     Name  Year Gender  Count
# 1792389  1792390     Emma  2014      F  20799
# 1792390  1792391   Olivia  2014      F  19674
# 1811456  1811457     Noah  2014      M  19144
# 1792391  1792392   Sophia  2014      F  18490
# 1811457  1811458     Liam  2014      M  18342
# ...          ...      ...   ...    ...    ...
# 1825424  1825425  Zmarion  2014      M      5
# 1825423  1825424   Ziyang  2014      M      5
# 1825422  1825423    Ziyah  2014      M      5
# 1825421  1825422    Zivon  2014      M      5
# 1825420  1825421    Zirui  2014      M      5
#
# [33044 rows x 5 columns]

# %%
sorted_us_2014 = us_babies_2014.sort_values('Count', ascending=False)

sorted_us_2014.iloc[0:5]
# Out:
#               Id    Name  Year Gender  Count
# 1792389  1792390    Emma  2014      F  20799
# 1792390  1792391  Olivia  2014      F  19674
# 1811456  1811457    Noah  2014      M  19144
# 1792391  1792392  Sophia  2014      F  18490
# 1811457  1811458    Liam  2014      M  18342

# %%
us_babies.head(10)
# shows first 10 rows
# Out:
#    Id       Name  Year Gender  Count
# 0   1       Mary  1880      F   7065
# 1   2       Anna  1880      F   2604
# 2   3       Emma  1880      F   2003
# 3   4  Elizabeth  1880      F   1939
# 4   5     Minnie  1880      F   1746
# 5   6   Margaret  1880      F   1578
# 6   7        Ida  1880      F   1472
# 7   8      Alice  1880      F   1414
# 8   9     Bertha  1880      F   1320
# 9  10      Sarah  1880      F   1288

# %%
us_babies.tail(20)
#Shows Last 20 Rows
# Out:
#               Id     Name  Year Gender  Count
# 1825413  1825414     Ziar  2014      M      5
# 1825414  1825415   Zichen  2014      M      5
# 1825415  1825416    Ziden  2014      M      5
# 1825416  1825417   Zierre  2014      M      5
# 1825417  1825418    Ziion  2014      M      5
# 1825418  1825419    Zijun  2014      M      5
# 1825419  1825420    Zilas  2014      M      5
# 1825420  1825421    Zirui  2014      M      5
# 1825421  1825422    Zivon  2014      M      5
# 1825422  1825423    Ziyah  2014      M      5
# 1825423  1825424   Ziyang  2014      M      5
# 1825424  1825425  Zmarion  2014      M      5
# 1825425  1825426       Zo  2014      M      5
# 1825426  1825427    Zyeir  2014      M      5
# 1825427  1825428     Zyel  2014      M      5
# 1825428  1825429   Zykeem  2014      M      5
# 1825429  1825430   Zymeer  2014      M      5
# 1825430  1825431  Zymiere  2014      M      5
# 1825431  1825432    Zyran  2014      M      5
# ...

# %%
us_babies.shape
# Show Number of Rows and Columns
# Out:
# (1825433, 5)

# %%
#Show Column Names
us_babies.columns
# Out:
# Index(['Id', 'Name', 'Year', 'Gender', 'Count'], dtype='str')

# %%
# Show Column Names
us_babies.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1825433 entries, 0 to 1825432
# Data columns (total 5 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   Id      int64
#  1   Name    str
#  2   Year    int64
#  3   Gender  str
#  4   Count   int64
# dtypes: int64(3), str(2)
# memory usage: 69.6 MB

# %%
# basic Statistic
us_babies.describe()
# Out:
#                  Id          Year         Count
# count  1.825433e+06  1.825433e+06  1.825433e+06
# mean   9.127170e+05  1.972620e+03  1.846879e+02
# std    5.269573e+05  3.352891e+01  1.566711e+03
# min    1.000000e+00  1.880000e+03  5.000000e+00
# 25%    4.563590e+05  1.949000e+03  7.000000e+00
# 50%    9.127170e+05  1.982000e+03  1.200000e+01
# 75%    1.369075e+06  2.001000e+03  3.200000e+01
# max    1.825433e+06  2.014000e+03  9.968000e+04

# %%
# Find Most Popular Baby Names
us_babies.sort_values(by='Count', ascending=False).head()
# Out:
#             Id     Name  Year Gender  Count
# 431052  431053    Linda  1947      F  99680
# 441424  441425    Linda  1948      F  96205
# 437157  437158    James  1947      M  94755
# 544602  544603  Michael  1957      M  92709
# 437158  437159   Robert  1947      M  91642

# %%
# Show Only Female Names
us_babies[us_babies['Gender'] == 'F'].head(200)
# Out:
#       Id       Name  Year Gender  Count
# 0      1       Mary  1880      F   7065
# 1      2       Anna  1880      F   2604
# 2      3       Emma  1880      F   2003
# 3      4  Elizabeth  1880      F   1939
# 4      5     Minnie  1880      F   1746
# ..   ...        ...   ...    ...    ...
# 195  196      Roxie  1880      F     62
# 196  197    Cynthia  1880      F     61
# 197  198     Helena  1880      F     60
# 198  199      Hilda  1880      F     60
# 199  200      Hulda  1880      F     60
#
# [200 rows x 5 columns]

# %%
# Show Only Female Names
us_babies[us_babies['Gender'] == 'M'].head(200)
# Out:
#         Id     Name  Year Gender  Count
# 942    943     John  1880      M   9655
# 943    944  William  1880      M   9532
# 944    945    James  1880      M   5927
# 945    946  Charles  1880      M   5348
# 946    947   George  1880      M   5126
# ...    ...      ...   ...    ...    ...
# 1137  1138    Pearl  1880      M     62
# 1138  1139  Russell  1880      M     62
# 1139  1140  Solomon  1880      M     62
# 1140  1141     Arch  1880      M     61
# 1141  1142      Asa  1880      M     60
#
# [200 rows x 5 columns]

# %%
# Show Random Rows
us_babies.sample(30)
# Out:
#               Id       Name  Year Gender  Count
# 791054    791055      Debra  1976      F   2070
# 273112    273113      Gearl  1929      M      9
# 515272    515273      Norma  1955      F   2931
# 1567297  1567298       Erna  2007      F      7
# 963905    963906     Ruthie  1985      F     36
# 1822031  1822032     Yamato  2014      M      7
# 652270    652271   Gennetta  1966      F      5
# 767957    767958    Wakisha  1974      F      5
# 298945    298946    Ventura  1932      F      5
# 612485    612486   Maryanna  1963      F     13
# 936380    936381      Nader  1983      M     27
# 130951    130952     Barbra  1916      F     18
# 1723055  1723056    Prestan  2011      M      6
# 69177      69178  Fairbanks  1904      M      6
# 1562097  1562098   Giavonni  2007      F     13
# 1454057  1454058     Suyash  2003      M      5
# 1320401  1320402      Satia  1999      F      5
# 436400    436401    Armella  1947      F      5
# 477467    477468    Mirella  1951      F      6
# ...

# %%
# Display the entire Year column from the dataset
us_babies['Year']
# Out:
# 0          1880
# 1          1880
# 2          1880
# 3          1880
# 4          1880
#            ...
# 1825428    2014
# 1825429    2014
# 1825430    2014
# 1825431    2014
# 1825432    2014
# Name: Year, Length: 1825433, dtype: int64

# %%
# Check whether each row has Year equal to 2014
# Returns True or False for every row
us_babies['Year'] == 2014
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 1825428     True
# 1825429     True
# 1825430     True
# 1825431     True
# 1825432     True
# Name: Year, Length: 1825433, dtype: bool

# %%
# Select only rows where the Year is 2014
# The colon (:) means include all columns
us_babies.loc[us_babies['Year'] == 2014, :]
# Out:
#               Id      Name  Year Gender  Count
# 1792389  1792390      Emma  2014      F  20799
# 1792390  1792391    Olivia  2014      F  19674
# 1792391  1792392    Sophia  2014      F  18490
# 1792392  1792393  Isabella  2014      F  16950
# 1792393  1792394       Ava  2014      F  15586
# ...          ...       ...   ...    ...    ...
# 1825428  1825429    Zykeem  2014      M      5
# 1825429  1825430    Zymeer  2014      M      5
# 1825430  1825431   Zymiere  2014      M      5
# 1825431  1825432     Zyran  2014      M      5
# 1825432  1825433     Zyrin  2014      M      5
#
# [33044 rows x 5 columns]

# %%
# Save only 2014 baby name records into a new DataFrame
us_babies_2014 = us_babies.loc[us_babies['Year'] == 2014, :]

# %%
# Display the filtered 2014 dataset
us_babies_2014
# Out:
#               Id      Name  Year Gender  Count
# 1792389  1792390      Emma  2014      F  20799
# 1792390  1792391    Olivia  2014      F  19674
# 1792391  1792392    Sophia  2014      F  18490
# 1792392  1792393  Isabella  2014      F  16950
# 1792393  1792394       Ava  2014      F  15586
# ...          ...       ...   ...    ...    ...
# 1825428  1825429    Zykeem  2014      M      5
# 1825429  1825430    Zymeer  2014      M      5
# 1825430  1825431   Zymiere  2014      M      5
# 1825431  1825432     Zyran  2014      M      5
# 1825432  1825433     Zyrin  2014      M      5
#
# [33044 rows x 5 columns]

# %%
# Sort baby names by Count from highest to lowest
us_babies_2014.sort_values('Count', ascending=False)
# Out:
#               Id     Name  Year Gender  Count
# 1792389  1792390     Emma  2014      F  20799
# 1792390  1792391   Olivia  2014      F  19674
# 1811456  1811457     Noah  2014      M  19144
# 1792391  1792392   Sophia  2014      F  18490
# 1811457  1811458     Liam  2014      M  18342
# ...          ...      ...   ...    ...    ...
# 1825424  1825425  Zmarion  2014      M      5
# 1825423  1825424   Ziyang  2014      M      5
# 1825422  1825423    Ziyah  2014      M      5
# 1825421  1825422    Zivon  2014      M      5
# 1825420  1825421    Zirui  2014      M      5
#
# [33044 rows x 5 columns]

# %%
# Display the first 5 rows of the sorted dataset
sorted_us_2014.iloc[0:5]
# Out:
#               Id    Name  Year Gender  Count
# 1792389  1792390    Emma  2014      F  20799
# 1792390  1792391  Olivia  2014      F  19674
# 1811456  1811457    Noah  2014      M  19144
# 1792391  1792392  Sophia  2014      F  18490
# 1811457  1811458    Liam  2014      M  18342

# %%
# Find the highest baby name count
us_babies['Count'].max()
# Out:
# np.int64(99680)

# %%
# Calculate the average baby name count
us_babies['Count'].mean()
# Out:
# np.float64(184.68792116719703)

# %%
# Save the sorted 2014 data into a new variable
sorted_us_2014 = us_babies_2014.sort_values('Count', ascending=False)

# %%
sorted_us_2014
# Out:
#               Id     Name  Year Gender  Count
# 1792389  1792390     Emma  2014      F  20799
# 1792390  1792391   Olivia  2014      F  19674
# 1811456  1811457     Noah  2014      M  19144
# 1792391  1792392   Sophia  2014      F  18490
# 1811457  1811458     Liam  2014      M  18342
# ...          ...      ...   ...    ...    ...
# 1825424  1825425  Zmarion  2014      M      5
# 1825423  1825424   Ziyang  2014      M      5
# 1825422  1825423    Ziyah  2014      M      5
# 1825421  1825422    Zivon  2014      M      5
# 1825420  1825421    Zirui  2014      M      5
#
# [33044 rows x 5 columns]

# %%
# Display the entire Name column
us_babies['Name']
# Out:
# 0               Mary
# 1               Anna
# 2               Emma
# 3          Elizabeth
# 4             Minnie
#              ...
# 1825428       Zykeem
# 1825429       Zymeer
# 1825430      Zymiere
# 1825431        Zyran
# 1825432        Zyrin
# Name: Name, Length: 1825433, dtype: str

# %%
# Display the entire Year column
us_babies['Year']
# Out:
# 0          1880
# 1          1880
# 2          1880
# 3          1880
# 4          1880
#            ...
# 1825428    2014
# 1825429    2014
# 1825430    2014
# 1825431    2014
# 1825432    2014
# Name: Year, Length: 1825433, dtype: int64

# %%
# Display dataset information and data types
us_babies.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1825433 entries, 0 to 1825432
# Data columns (total 5 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   Id      int64
#  1   Name    str
#  2   Year    int64
#  3   Gender  str
#  4   Count   int64
# dtypes: int64(3), str(2)
# memory usage: 69.6 MB

# %%
# Display rows 0 through 4 from the sorted dataset
sorted_us_2014.iloc[0:5]
# Out:
#               Id    Name  Year Gender  Count
# 1792389  1792390    Emma  2014      F  20799
# 1792390  1792391  Olivia  2014      F  19674
# 1811456  1811457    Noah  2014      M  19144
# 1792391  1792392  Sophia  2014      F  18490
# 1811457  1811458    Liam  2014      M  18342

# %%
# Display the first row only
sorted_us_2014.iloc[0]
# Out:
# Id        1792390
# Name         Emma
# Year         2014
# Gender          F
# Count       20799
# Name: 1792389, dtype: object

# %%
# Display the first 10 rows
sorted_us_2014.iloc[0:10]
# Out:
#               Id      Name  Year Gender  Count
# 1792389  1792390      Emma  2014      F  20799
# 1792390  1792391    Olivia  2014      F  19674
# 1811456  1811457      Noah  2014      M  19144
# 1792391  1792392    Sophia  2014      F  18490
# 1811457  1811458      Liam  2014      M  18342
# 1811458  1811459     Mason  2014      M  17092
# 1792392  1792393  Isabella  2014      F  16950
# 1811459  1811460     Jacob  2014      M  16712
# 1811460  1811461   William  2014      M  16687
# 1811461  1811462     Ethan  2014      M  15619

# %%
# Display rows 10 through 19
sorted_us_2014.iloc[10:20]
# Out:
#               Id       Name  Year Gender  Count
# 1792393  1792394        Ava  2014      F  15586
# 1811462  1811463    Michael  2014      M  15323
# 1811463  1811464  Alexander  2014      M  15293
# 1811464  1811465      James  2014      M  14301
# 1811465  1811466     Daniel  2014      M  13829
# 1811466  1811467     Elijah  2014      M  13694
# 1811467  1811468   Benjamin  2014      M  13687
# 1811468  1811469      Logan  2014      M  13579
# 1792394  1792395        Mia  2014      F  13442
# 1811469  1811470      Aiden  2014      M  13296

# %%
# Display rows 0, 5, and 10
sorted_us_2014.iloc[[0, 5, 10]]
# Out:
#               Id   Name  Year Gender  Count
# 1792389  1792390   Emma  2014      F  20799
# 1811458  1811459  Mason  2014      M  17092
# 1792393  1792394    Ava  2014      F  15586

# %%
# Display rows 0 through 4 and columns 1 through 3
sorted_us_2014.iloc[0:5, 1:4]
# Out:
#            Name  Year Gender
# 1792389    Emma  2014      F
# 1792390  Olivia  2014      F
# 1811456    Noah  2014      M
# 1792391  Sophia  2014      F
# 1811457    Liam  2014      M

# %%
# Create a new DataFrame containing only rows where the Name is John
us_john = us_babies.loc[us_babies['Name'] == 'John', :]

# %%
# Display all rows for the name John
us_john
# Out:
#               Id  Name  Year Gender  Count
# 228          229  John  1880      F     46
# 942          943  John  1880      M   9655
# 2312        2313  John  1881      F     26
# 2938        2939  John  1881      M   8769
# 4212        4213  John  1882      F     40
# ...          ...   ...   ...    ...    ...
# 1744997  1744998  John  2012      M  10593
# 1766701  1766702  John  2013      F     16
# 1778403  1778404  John  2013      M  10670
# 1800575  1800576  John  2014      F     14
# 1811481  1811482  John  2014      M  10600
#
# [270 rows x 5 columns]

# %%
# Install matplotlib for charts and graphs
# !pip install matplotlib

# %%
# Import pandas library
import pandas as pd

# %%
# Read the US baby names dataset
us_babies = pd.read_csv(
    r'D:\MiniForge\Ex_Files_Intro_to_Data_Science\Ex_Files_Intro_to_Data_Science\Exercise Files\us_baby_names.csv'
)

# %%
# Create a new DataFrame containing only rows where the Name is John
us_john = us_babies.loc[us_babies['Name'] == 'John', :]

# %%
# Display all rows for the name John
us_john
# Out:
#               Id  Name  Year Gender  Count
# 228          229  John  1880      F     46
# 942          943  John  1880      M   9655
# 2312        2313  John  1881      F     26
# 2938        2939  John  1881      M   8769
# 4212        4213  John  1882      F     40
# ...          ...   ...   ...    ...    ...
# 1744997  1744998  John  2012      M  10593
# 1766701  1766702  John  2013      F     16
# 1778403  1778404  John  2013      M  10670
# 1800575  1800576  John  2014      F     14
# 1811481  1811482  John  2014      M  10600
#
# [270 rows x 5 columns]

# %%
# Create a horizontal bar chart showing how frequently the name John occurred over the years
us_john.plot.barh(x='Year', y='Count')
# Out:
# <Axes: ylabel='Year'>
